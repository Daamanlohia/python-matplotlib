# %%
# """visualization of Data
1.using matplotlib
a>scatter plot 
b>histogram
c>bar chart
2.using sea born

PLOTLIB
"""

# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import pandas as pd
a = np.linspace(0, 10, 100)
plt.plot(a, a, label='axis')
plt.legend()
plt.show()

# %%
df = pd.read_csv('C:\Users\student\Desktop\Book1.csv')
graph = px.line(df, x = 'MARVEL', y = 'DC', title='COMIC UNIVERSE')
graph.show()
# Out:
#   File "<ipython-input-14-2f07c9e1e71b>", line 1
#     df = pd.read_csv('C:\Users\student\Desktop\Book1.csv')
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, '*', color='green');
